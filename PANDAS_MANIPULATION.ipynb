# %%
import pandas as pd

# %%
df=pd.read_csv("https://github.com/plotly/datasets/raw/master/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.head(177)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 172            2       87              0             23        0  28.9
# 173            1       79             60             42       48  43.5
# 174            2       75             64             24       55  29.7
# 175            8      179             72             42      130  32.7
# 176            6       85             78              0        0  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.tail(29)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 739            1      102             74              0        0  39.5
# 740           11      120             80             37      150  42.3
# 741            3      102             44             20       94  30.8
# 742            1      109             58             18      116  28.5
# 743            9      140             94              0        0  32.7
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 746            1      147             94             41        0  49.3
# 747            1       81             74             41       57  46.3
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# ...

# %%
df=pd.read_csv("https://github.com/plotly/datasets/raw/master/diabetes.csv",header=None)

# %%
df
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2=pd.read_csv("https://github.com/plotly/datasets/raw/master/diabetes.csv",header=None,skiprows=[1,3,5,7,9,11,13])

# %%
df2
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              1       85             66             29        0  26.6
# 2              1       89             66             23       94  28.1
# 3              5      116             74              0        0  25.6
# 4             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 757           10      101             76             48      180  32.9
# 758            2      122             70             27        0  36.8
# 759            5      121             72             23      112  26.2
# 760            1      126             60              0        0  30.1
# 761            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df2.to_csv('bhanu.csv')

# %%
df2.to_csv('bhanu.csv',index=False)
df2
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              1       85             66             29        0  26.6
# 2              1       89             66             23       94  28.1
# 3              5      116             74              0        0  25.6
# 4             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 757           10      101             76             48      180  32.9
# 758            2      122             70             27        0  36.8
# 759            5      121             72             23      112  26.2
# 760            1      126             60              0        0  30.1
# 761            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df2.tail()
# Out:
#       0    1   2   3    4     5      6   7  8
# 757  10  101  76  48  180  32.9  0.171  63  0
# 758   2  122  70  27    0  36.8   0.34  27  0
# 759   5  121  72  23  112  26.2  0.245  30  0
# 760   1  126  60   0    0  30.1  0.349  47  1
# 761   1   93  70  31    0  30.4  0.315  23  0

# %%
df2.head()
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            1       85             66             29        0  26.6
# 2            1       89             66             23       94  28.1
# 3            5      116             74              0        0  25.6
# 4           10      115              0              0        0  35.3
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.167   21        0
# 3                     0.201   30        0
# 4                     0.134   29        0

# %%
df=pd.read_csv("https://github.com/plotly/datasets/raw/master/diabetes.csv")
df
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
 df[df.dtypes[df.dtypes == 'int64'].index].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
pd.Categorical(df)
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
# Categories (9, object): ['Age', 'BMI', 'BloodPressure', 'DiabetesPedigreeFunction', ...,
#                          'Insulin', 'Outcome', 'Pregnancies', 'SkinThickness']

# %%
pd.Categorical(df["Glucose"])
# Out:
# [148, 85, 183, 89, 137, ..., 101, 122, 121, 126, 93]
# Length: 768
# Categories (136, int64): [0, 44, 56, 57, ..., 196, 197, 198, 199]

# %%
dty=df.dtypes
dty
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
dty['Age']
# Out:
# dtype('int64')

# %%
df['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df["BMI"][::-8]
# Out:
# 767    30.4
# 759    35.5
# 751    39.0
# 743    32.7
# 735    35.4
#        ...
# 39     37.1
# 31     31.6
# 23     29.0
# 15     30.0
# 7      35.3
# Name: BMI, Length: 96, dtype: float64
